# %% [markdown]
# # Regras Regex 2 a 6

# %% [markdown]
# ### Importações

# %%
import re
import pandas as pd

from os import listdir
from os.path import isfile, join

# %% [markdown]
# ### Regras e Padrões a serem extraidos

# %%
df = pd.DataFrame([["Quadro pessoal permanente ou Suplementar", "Após padrão, começa com 'do Quadro'"],
                  ["Fundamento Legal", "Começa com 'nos termos do'"],
                  ["Processo GDF/SEI", "Começa com 'Processo SEI'"],
                  ["Símbolo", "Após 'Símbolo'"],
                  ["Cargo em Comissão", "Após Simbolo"]],
                  index = [2, 3, 4, 5, 6],
                  columns = ["Atributo", "Padrão"])

style_df = pd.DataFrame(df).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
style_df
# Out:
# <style  type="text/css" >
#     #T_36e8e9ea_9ada_11ea_982a_784f43715d3e th {
#           text-align: left;
#     }    #T_36e8e9ea_9ada_11ea_982a_784f43715d3erow0_col0 {
#             text-align:  left;
#         }    #T_36e8e9ea_9ada_11ea_982a_784f43715d3erow0_col1 {
#             text-align:  left;
#         }    #T_36e8e9ea_9ada_11ea_982a_784f43715d3erow1_col0 {
#             text-align:  left;
#         }    #T_36e8e9ea_9ada_11ea_982a_784f43715d3erow1_col1 {
#             text-align:  left;
#         }    #T_36e8e9ea_9ada_11ea_982a_784f43715d3erow2_col0 {
#             text-align:  left;
#         }    #T_36e8e9ea_9ada_11ea_982a_784f43715d3erow2_col1 {
#             text-align:  left;
#         }    #T_36e8e9ea_9ada_11ea_982a_784f43715d3erow3_col0 {
#             text-align:  left;
#         }    #T_36e8e9ea_9ada_11ea_982a_784f43715d3erow3_col1 {
#             text-align:  left;
#         }    #T_36e8e9ea_9ada_11ea_982a_784f43715d3erow4_col0 {
#             text-align:  left;
#         }    #T_36e8e9ea_9ada_11ea_982a_784f43715d3erow4_col1 {
#             text-align:  left;
#         }</style><table id="T_36e8e9ea_9ada_11ea_982a_784f43715d3e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Atributo</th>        <th class="col_heading level0 col1" >Padrão</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_36e8e9ea_9ada_11ea_982a_784f43715d3elevel0_row0" class="row_heading level0 row0" >2</th>
#                         <td id="T_36e8e9ea_9ada_11ea_982a_784f43715d3erow0_col0" class="data row0 col0" >Quadro pessoal permanente ou Suplementar</td>
#                         <td id="T_36e8e9ea_9ada_11ea_982a_784f43715d3erow0_col1" class="data row0 col1" >Após padrão, começa com 'do Quadro'</td>
#             </tr>
#             <tr>
#                         <th id="T_36e8e9ea_9ada_11ea_982a_784f43715d3elevel0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_36e8e9ea_9ada_11ea_982a_784f43715d3erow1_col0" class="data row1 col0" >Fundamento Legal</td>
#                         <td id="T_36e8e9ea_9ada_11ea_982a_784f43715d3erow1_col1" class="data row1 col1" >Começa com 'nos termos do'</td>
#             </tr>
#             <tr>
#                         <th id="T_36e8e9ea_9ada_11ea_982a_784f43715d3elevel0_row2" class="row_heading level0 row2" >4</th>
#                         <td id="T_36e8e9ea_9ada_11ea_982a_784f43715d3erow2_col0" class="data row2 col0" >Processo GDF/SEI</td>
#                         <td id="T_36e8e9ea_9ada_11ea_982a_784f43715d3erow2_col1" class="data row2 col1" >Começa com 'Processo SEI'</td>
#             </tr>
#             <tr>
#                         <th id="T_36e8e9ea_9ada_11ea_982a_784f43715d3elevel0_row3" class="row_heading level0 row3" >5</th>
#                         <td id="T_36e8e9ea_9ada_11ea_982a_784f43715d3erow3_col0" class="data row3 col0" >Símbolo</td>
#                         <td id="T_36e8e9ea_9ada_11ea_982a_784f43715d3erow3_col1" class="data row3 col1" >Após 'Símbolo'</td>
#             </tr>
#             <tr>
#                         <th id="T_36e8e9ea_9ada_11ea_982a_784f43715d3elevel0_row4" class="row_heading level0 row4" >6</th>
#                         <td id="T_36e8e9ea_9ada_11ea_982a_784f43715d3erow4_col0" class="data row4 col0" >Cargo em Comissão</td>
#                         <td id="T_36e8e9ea_9ada_11ea_982a_784f43715d3erow4_col1" class="data row4 col1" >Após Simbolo</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Funções de Auxilio

# %%
def get_txts(path):
    years = [join(path, x) for x in listdir(path) if not isfile(join(path, x))]
    txts = []
    for year in years:
        months = [join(year, x) for x in listdir(year) if not isfile(join(year, x))]
        for month in months:
            txts += [join(month, x) for x in listdir(month) if isfile(join(month, x))]
    return txts

def execute_regex(rule, txt):
    return re.findall(rule, txt)

# %% [markdown]
# ### Diretórios

# %%
dodfs_space_dir = "./data/dodfs_txt_espaco"
dodfs_space_files = get_txts(dodfs_space_dir)

dodfs_n_dir = "./data/dodfs_txt_barra_n"
dodfs_n_files = get_txts(dodfs_n_dir)

output = "./results"

# %% [markdown]
# ### Regras Regex

# %%
quadro_rule = "d?[e|a|o]?(Quadro[\s\S]*?)[,|;|.]"
fundamento_rule = "nos\stermos\sd[o|a|e]s?\s([\s\S]*?)[.|;|,]"
seiproc_rule = "[(Processo|processo|PROCESSO)]\s[S|s][E|e][I|i][:|\s][n|N]?o?\s([\s\S]*?)[;|,|.]"
simbolo_rule = "Simbolo\s([\s\S]*?),"
comission_rule = "Simbolo\s[\s\S]*?,\sd[e|a|o]\s([\s\S]*?),"

rules = [quadro_rule, fundamento_rule, seiproc_rule, simbolo_rule, comission_rule]

# %% [markdown]
# #### Extrai todos os atributos da base de dados

# %%
res = []
for rule in rules:
    rule_output = []
    for file in dodfs_n_files:
        file_open = open(file, "r")
        txt = file_open.read()
        rule_output += execute_regex(rule, txt)
        file_open.close()
    res.append(rule_output)
res[1]
# Out:
# ['que aponta o Relatorio em referencia',
#  'art',
#  'art',
#  'art',
#  'art',
#  'art',
#  'art',
#  'art',
#  'Art',
#  'Art',
#  'Lei no 5',
#  'Lei no 5',
#  'Lei no 5',
#  'clausula de inadimplencia do\ncontrato original',
#  'clausula de inadimplencia do contrato original',
#  'clausula de inadimplencia',
#  'voto do Diretor-Relator',
#  'voto do Diretor-Relator',
#  'voto do Diretor-Relator',
#  'voto do Diretor- R e l a t o r',
#  'voto do Diretor-Relator',
#  '2o',
#  'legislacao vigente',
#  'art',
#  'art',
#  'item II',
#  'art',
#  'Enunciado no 20 das\nSumulas da Jurisprudencia desta Corte de Contas',
#  'art',
#  'art',
#  'item VIII',
#  'decidido pelo TJDFT na ADI 2017',
#  'item III da Decisao TCDF n',
#  'voto proferido pelo Relator deste feito',
#  'art',
#  'Voto proferido pelo\nRelator',
#  'artigos 24',
#  'voto proferido pelo Relator',
#  'Decisao no 6388/2016 e do\nAcordao no 842/2016',
#  'voto proferido pelo Relator deste feito',
#  'voto proferido pelo Relator deste feito',
#  'voto proferido pelo Relator deste feito',
#  'artigos 7o',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 6o da Emenda Constitucional no 41/2003',
#  'artigo 6o da Emenda Constitucional no 41/2003',
#  'artigo 6o da Emenda Constitucional no 41/2003',
#  'artigo 40',
#  'artigo 40',
#  'Lei Complementar 840/2011',
#  'art',
#  'art',
#  'ato em que os designar',
#  'delegacao de competencia prevista no artigo 1o',
#  'delegacao de competencia prevista no artigo 1o',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'Portaria PMDF de 10 de marco de 2003',
#  'Instrucao Normativa no 01',
#  'caput do Artigo 51',
#  'Artigo 50',
#  'processo Sei no 00150',
#  'art',
#  'art',
#  'artigo 3o',
#  'caput do\nart',
#  'Projeto Basico e Parecer no',
#  ' 6 do art',
#  ' 6 do art',
#  ' 6 do art',
#  'art',
#  'art',
#  'art',
#  'art',
#  'art',
#  'art',
#  'art',
#  'Anexos I',
#  'Anexos I',
#  'art',
#  'art',
#  'art',
#  'art',
#  'art',
#  'Decreto no 39',
#  'Processo\nSEIGDF no 00040-00018415/2019-17',
#  'Decisao no\n6285/2016',
#  'art',
#  'Decisao no\n6285/2016',
#  'Decisao no\n6285/2016',
#  'caput do Art',
#  'Leis nos 3320',
#  'Decreto\nn 34',
#  'artigo 139 ao artigo 143',
#  'Art',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 1o',
#  'artigo 1o',
#  'artigo 1o',
#  'artigo 1o',
#  'artigo 1o',
#  'artigo 1o',
#  'artigo 1o',
#  'artigo 1o',
#  'artigo 1o',
#  'artigo 1o',
#  'artigo 1o',
#  'artigo\n96',
#  'artigo 62',
#  'Processo SEI no',
#  'art',
#  'inciso V do art',
#  'inciso V do art',
#  'inciso V do\nart',
#  'Contrato de\nCessao de Uso',
#  'artigo 26',
#  'art',
#  'art',
#  'art',
#  'art',
#  'Decreto no 39',
#  'art',
#  'Oficio SEI-GDF No 547/2019 - CACI/GAB',
#  ' 1o deste\nartigo',
#  'paragrafo 1o do artigo cujo controle de acesso sera\nregulamentado por ato do Poder Publico Municipal',
#  'paragrafo primeiro\ndesse artigo cujo controle de acesso sera regulamentado por ato de poder publico municipal',
#  'Lei no 3',
#  'MANIFESTACAO\nTECNICA 1722 - IBRAM/PRESI/SULAM/DILAM IV\nEDSON DUARTE\nPresidente\nDEFENSORIA PUBLICA DO DISTRITO FEDERAL\nSUBSECRETARIA DE ADMINISTRACAO-GERAL\nORDEM DE SERVICO No 105',
#  'art',
#  'arts',
#  'art',
#  'Lei Complementar no 435/2001',
#  'paragrafo unico do art',
#  'Decisao no 6069/17 (item III)',
#  'Decreto no 39',
#  'artigo 3o',
#  'Paragrafo unico',
#  'legislacao vigente',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo\n50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo\n50',
#  'caput do Artigo 51',
#  'artigo\n50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do\nArtigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput\ndo Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'artigo 50',
#  'artigo 50',
#  'artigo 50',
#  'artigo 50',
#  'artigo 50',
#  'caput\ndo Artigo 51',
#  'artigo\n50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput\ndo Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput  do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput\ndo Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  ' caput do  Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput\ndo Artigo 51',
#  'artigo 50',
#  'caput do\nArtigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput\ndo Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo\n50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput\ndo Artigo 51',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'caput\ndo Artigo 51',
#  'artigo\n50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'processo: 00060-00138093/2018-68',
#  'artigo 50',
#  'artigo 50',
#  'artigo 54',
#  'artigo 50',
#  'caput do Artigo 51',
#  'artigo 50',
#  'processo: 0279-001633/2016',
#  'artigo 50',
#  'Lei\ncomplementar 840 de 23/11/2011 e Lei no 221/90',
#  'Lei Complementar 840/2011',
#  'artigos 139 a 143',
#  'artigo 40',
#  'artigo\n40',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'artigo 3o',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'Artigo 25',
#  'artigos',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos\n87',
#  'artigo 50\nda Lei no 10',
#  'artigos 88',
#  'artigo 20',
#  'artigos 88',
#  'artigo 20',
#  'artigo 96 da Lei Complementar no\n840',
#  'art',
#  'Chamada Publica n 02/2016 - SEEDF',
#  'Artigo 25',
#  'Artigo 26 do mesmo diploma legal a\ninexigibilidade de licitacao',
#  'art',
#  'Acordao no 6',
#  'Lei no 4',
#  'artigo 26 da Lei no 8',
#  'artigo 26 da Lei no 8',
#  'artigo 26 da Lei no 8',
#  'Edital Normativo no 1',
#  'disposto nos subitens 10',
#  'Edital Normativo no 1',
#  'Lei no 13',
#  'incisos I a VI do art',
#  'art',
#  'disposto nos subitens 11',
#  'art',
#  'art',
#  'art',
#  "Alinea 'a' do\nItem III do Paragrafo Unico do Artigo 2o da Lei no 1",
#  'Inciso I do\nArtigo 3o do RICMS',
#  'disposto na alinea "a" do inciso I do art',
#  "que dispoe a Alinea 'a' do Inciso I do art",
#  'inciso III do artigo 89 do Decreto no 35',
#  'Lei Distrital no 6',
#  'legislacao vigente',
#  'BNCC',
#  'Resolucao no 02/2012-FDR',
#  'Resolucao no 06/2016-\nFDR',
#  'Decreto de 2017 e o Processo no 45',
#  'Decreto de 2017',
#  'Decreto de 2015',
#  'Decreto de 2013 e',
#  'Decreto de 2017',
#  'Decreto de 2014',
#  'Decreto de 2017',
#  'Decreto de 2017 e o de no 15',
#  'Decreto\nde 2017',
#  'Decreto de 2010',
#  'Decretos de 2015 e 2017',
#  'Decreto de 2015 e o de n 16',
#  'Decreto de 2017',
#  'Decreto de 2011',
#  'Decreto\nde 2017',
#  'Decretos\nde 2011',
#  'Decreto\nde 2015',
#  'Decreto de 2014',
#  'Decreto de 2017',
#  'Decreto de 2014 e',
#  'Decreto de 2017',
#  'Decreto de2017',
#  'Decreto de 2017',
#  'Decretos de 2013',
#  'Decreto de 2011',
#  'Decreto de 2016 e 2017',
#  'Decreto de 2015',
#  'Decreto de 2017 e o de n 967-14',
#  'Decreto de 2012',
#  'Decreto de 2017',
#  'Decreto de 2017',
#  'Decreto de 2003',
#  'Decreto de 2017',
#  'Decreto de 2017',
#  'Decreto de 2017',
#  'Decretos de 2013',
#  'Decreto de 2017',
#  'Decreto de 2017',
#  'Decreto de 2017 e o Processo no 24',
#  'Decreto de 2017',
#  'Decreto de2016 e pelo deferimento de indulto',
#  'Decreto de 2015',
#  'Decreto de 2017',
#  'Decreto de 2017',
#  'Decreto de 2017 e o Processo no 3',
#  'Decreto de 2017',
#  'Decreto de 2017',
#  'Decreto de 2017',
#  'Decreto de 2017',
#  'Decreto de 2017',
#  'Decreto de 2017',
#  'Decreto de 2015',
#  'Decreto de 2017',
#  'Decreto de 2017',
#  'Decreto de 2017 e os Processos no 16',
#  'Decreto de 2017 e o de no 121',
#  'Decreto de 2017',
#  'Decreto de 2017 e o de no 14',
#  'Decreto de 2017',
#  'Decreto de 2017 e o de\nno 34',
#  'Decreto de 2011',
#  'art',
#  'Oficio SEI-GDF no 515/2019-GAG/GAB - Processo\n00010-00001172/2019-81 e do Oficio SEI-GDF no 518/2019-GAG/GAB - Processo 00010-\n00001175/2019-15',
#  'Lei no 13',
#  'Portaria no ___',
#  'Art',
#  'Portaria no ___',
#  'Portaria no ___',
#  'Resolucao CONAM no 11/2017',
#  'Portaria SECEC no 253',
#  'delegacao de competencia prevista no artigo 1o',
#  'artigo 2o',
#  'artigos 2o e 3o do Decreto no 37',
#  'artigo 2o do\nDecreto no 37',
#  'art',
#  'artigo 139',
#  'artigo 3o e 17 do Decreto no 37',
#  'artigos 2o e 3o do Decreto no 37',
#  'art',
#  'Lei Complementar no 840',
#  'Decreto no 22',
#  'art',
#  'art',
#  'art',
#  'art',
#  'artigo IV',
#  'artigo 12',
#  'artigo 30-A',
#  'artigo 30-A',
#  'artigo 30-A',
#  'artigo 30-A',
#  'artigo 30-A',
#  'artigo 30-A',
#  'artigo 30-A',
#  'artigo 30-A',
#  'artigo 40',
#  'artigo 18',
#  'Artigo 139 da Lei no 840/2011',
#  'Art',
#  'Artigo 133',
#  'artigo\n40',
#  'artigo 40',
#  'artigo 40',
#  'artigo\n40',
#  'artigo\n40',
#  'artigo\n40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo\n40',
#  'artigo\n40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo\n40',
#  'artigo 40',
#  'artigo 40',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'Artigo 6o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o\nda Emenda Constitucional no 41',
#  'Lei no 792 de\n10/11/1994',
#  'art',
#  'artigos: 87',
#  'Processo SEI-GDF no 00054-\n00057584/2019-14',
#  'artigos 87',
#  'artigos 87',
#  'artigos 87',
#  'artigos 87',
#  'contido no Relatorio SEI-GDF no 6/2019 - CBMDF/DISAU/ASSJU (22299408)',
#  'contido na Notificacao SEI-GDF no 39/2019 -\nCBMDF/DIGEP/SEPAG (23116346)',
#  'artigo 27',
#  'artigo 1o',
#  'Decreto No\n37',
#  'Decreto No 37',
#  'Resolucao Normativa no',
#  'documentacao constante nos autos\ndo Processo Eletronico SEI no',
#  'Resolucao Normativa no',
#  'documentacao\nconstante nos autos do Processo Eletronico SEI no 00400-00030914/2019-38',
#  'Resolucao Normativa no',
#  'documentacao constante nos autos do Processo Eletronico SEI no',
#  'art',
#  'art',
#  'art',
#  'art',
#  'art',
#  'artigo 26 da Lei 8',
#  'artigo 26 da Lei 8',
#  'artigo 24 da Lei no 8',
#  'artigo 24 da Lei no 8',
#  'art',
#  'legislacao vigente',
#  'artigo 2 do Decreto n 37',
#  'Edital',
#  'art',
#  'art',
#  'clausula de inadimplencia\ndo contrato original',
#  'clausula de inadimplencia do contrato original',
#  'clausula de inadimplencia',
#  'Anexo desta Portaria',
#  'inciso III do art',
#  'lei',
#  'art',
#  'art',
#  'art',
#  'Decisao no\n6285/2016',
#  'Decisao no 6285/2016',
#  'Decisao no\n6285/2016',
#  'art',
#  'Decisao no 6285/2016',
#  'Decisao no 6285/2016',
#  'Lei Complementar 840/2011',
#  'Lei complementar 840 de 23/11/2011 e Lei no 221/90',
#  'Art',
#  'Lei no13',
#  'artigo 40',
#  'artigo 40',
#  'Processo SEI no 00050-\n00008177/2019-96',
#  'Artigos 79 e 83',
#  'delegacao de competencia prevista no inciso V do art',
#  'Processo SEI/GDF no 00054-00022391/2019-42',
#  'artigos 87',
#  'artigos 87',
#  'artigos 87',
#  'artigos 87',
#  'art',
#  'arts',
#  'artigos 88',
#  'artigos 88',
#  'artigo 20',
#  'arts',
#  'art',
#  'arts',
#  'art',
#  'artigos 88',
#  'artigo 20',
#  'art',
#  'Instrucao Normativa - STC no 04',
#  'Decreto no 39',
#  'Decreto no 37',
#  'Lei',
#  'art',
#  'artigo 62',
#  'Edital no 1',
#  'disposto nos subitens 10',
#  'Oficio 4253/2019-BCB/Deorf/Difin',
#  'Art',
#  'inciso I',
#  'artigo 42 da Resolucao n',
#  'inciso I',
#  'artigo 42 da Resolucao n',
#  'inciso I',
#  'artigo 42 da Resolucao n',
#  'inciso I',
#  'artigo 42 da Resolucao n',
#  'inciso I',
#  'artigo 42 da Resolucao n',
#  'inciso I',
#  'artigo 42 da Resolucao n',
#  'Decreto no 24',
#  'artigo 144 da Lei Complementar n\n840/2011',
#  'art',
#  'art',
#  'artigo 190',
#  'artigos 47 da Lei no 8',
#  'artigos\n47 da Lei no 8',
#  'art',
#  'artigos 139 a 143',
#  'Art',
#  'Lei no 13',
#  'alinea "b"',
#  'delegacao de competencia prevista no inciso III do art',
#  'Processo SEI/GDF no 00054-00072737/2018-72',
#  'artigos 88',
#  'artigo 2o',
#  'artigos 88',
#  'arts',
#  'arts',
#  'arts',
#  'legislacao vigente',
#  'artigo 142',
#  'artigo 96',
#  'artigo 150',
#  'artigo 4o',
#  'artigo 139 da\nLei Complementar no 840',
#  'artigo 62',
#  'Lei Distrital no',
#  'Lei Distrital no',
#  'art',
#  'art',
#  'art',
#  'Artigo 26',
#  'artigo 26',
#  ' 2 do Artigo 113\ndo Decreto Distrital n 31',
#  'Artigo 26',
#  'artigo 26',
#  ' 2 do Artigo 113 do Decreto Distrital n 31',
#  'subitem 2',
#  'lei no 2',
#  'lei no 2',
#  'Decreto\nno 38',
#  'disposto no artigo 7o',
#  'Lei 11',
#  'Lei 11',
#  'artigo 9',
#  'artigo 30-A',
#  'Art',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'art',
#  'art',
#  'art',
#  'art',
#  'art',
#  'art',
#  'artigos 87',
#  'artigos 87',
#  'artigos 87',
#  'artigos 87',
#  'artigos 87',
#  'art',
#  'correspondente Lei Orcamentaria Anual',
#  'inciso I',
#  'Lei 6',
#  'art',
#  'art',
#  'art',
#  'caput',
#  'regulamento anexo',
#  ' 9o e 10 do art',
#  'art',
#  'Lei Distrital no 6',
#  'Relatorio\nTecnico apresentado pelo Grupo de Trabalho na ocasiao da 2o Reuniao Ordinaria de 2019 e 565o do\nCONEN-DF',
#  'deliberacao da 7o Reuniao Ordinaria de 2019 e 570o\ndo CONEN-DF',
#  'Lei Federal no\n11',
#  'legislacao vigente',
#  'art',
#  'Regulamento de Licitacoes e Contratos da Companhia',
#  'legislacao vigente',
#  'art',
#  'inciso I do caput do art',
#  'art',
#  'lei',
#  'legislacaopertinente',
#  'inciso III do art',
#  'Lei distrital no 4',
#  'art',
#  'art',
#  'Art',
#  'Art',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Artigo 139',
#  'Art',
#  'artigo 159 da Lei Complementar no 840',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'Artigo 6o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 3o',
#  'artigo 3o',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'Artigo 6o da Emenda Constitucional no 41',
#  'artigo 23',
#  'Decreto no 29',
#  'Decreto no 29',
#  'Decreto no 29',
#  'Decreto no 29',
#  'Decreto no 29',
#  'Decreto no 29',
#  'artigo 139 da Lei Complementar 840',
#  'artigo 114 da Lei\nComplementar no 840',
#  'artigo 40',
#  'artigo 3  da Emenda Constitucional no 47',
#  'artigo 40',
#  'artigo 40',
#  'artigo 3  da Emenda Constitucional no 47',
#  'artigo 3  da Emenda Constitucional no 47',
#  'artigo 40',
#  'artigo 40',
#  'artigo 3  da Emenda Constitucional no 47',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 3  da Emenda Constitucional no\n47',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo\n40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 40',
#  'artigo 3  da Emenda Constitucional no 47',
#  'artigo 40',
#  'art',
#  'artigo 17 da Lei no 5',
#  'artigo 17 da Lei no 5',
#  'artigo 17 da Lei no 5',
#  'delegacao de competencia prevista no art',
#  'artigos 60',
#  'artigo 1o',
#  'artigos 152 a 157 da LC 840/2011 c/c artigos 134',
#  'art',
#  'art',
#  'Decreto no 39',
#  'art',
#  'Artigo 25',
#  'Artigo 26 do mesmo diploma legal a inexigibilidade de licitacao',
#  'art',
#  'art',
#  'correspondente lei orcamentaria anual',
#  'artigo 63',
#  'que dispoe a Lei federal no 12',
#  'que dispoe a Lei federal no 12',
#  'lei vigente',
#  'MOC',
#  'Atestado de Implantacao Definitivo Pro-\nDF II no 029/2011',
#  'Ordem de Servico citada\nno art',
#  'art',
#  'legislacao de acesso\nvigente',
#  'art',
#  'artigo 2o do Decreto no 37',
#  'Decreto n 39',
#  'art',
#  'artigos 2o e 3o do Decreto no 37',
#  'Lei Complementar no 840/2011',
#  'Decreto no 37',
#  'DECRETO No 38',
#  'Lei 840/11',
#  'Lei 840/11',
#  'disposto no artigo 128',
#  'disposto no artigo 128',
#  'disposto no artigo 128 da Lei Complementar n',
#  'delegacao de competencia prevista no art',
#  'delegacao de competencia prevista no art',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'artigos: 87',
#  'Processo: 00054-00024461/2019-05',
#  'arts',
#  'art',
#  'arts',
#  'art',
#  'artigos 88',
#  'artigo 20',
#  'artigos 88',
#  'artigo 20',
#  'artigos 88',
#  'arts',
#  'artigos 88',
#  'artigos 88',
#  'arts',
#  'arts',
#  'artigos 20',
#  'Despacho no 09/2019-DGI (23534243)',
#  '1o do artigo 133 da Lei\nComplementar no 840/11',
#  'artigo 3o',
#  'artigo 1o',
#  'artigo 1o',
#  'artigo 142',
#  'artigo\n142',
#  'Portaria no 104',
#  'artigo 6o',
#  'inciso I do art',
#  'inciso II do art',
#  'art',
#  'artigo 26 da Lei no 8',
#  'artigo 26 da Lei no 8',
#  'artigo 26 da Lei no 8',
#  'artigo 26 da Lei no 8',
#  'Lei Complementar no\n840/2011 ou da Consolidacao das Leis do Trabalho (CLT)',
#  'Chamada\nPublica no 02/2016 - SEEDF',
#  'Artigo 25',
#  'Artigo 26 do mesmo diploma legal a inexigibilidade\nde licitacao',
#  'art',
#  'Acordao no 149/2019',
#  'Acordao no\n107/2019',
#  'Acordao no 109/2019',
#  'Acordao no\n126/2019',
#  'Acordao no 129/2019',
#  'Acordao no 148/2019',
#  'Acordao no 123/2019',
#  'Acordao no 44/2019',
#  'art',
#  'art',
#  'Anexo desta Portaria',
#  'art',
#  'artigo 1 e inciso II',
#  'Decisao no\n6285/2016',
#  'Decisao no\n6285/2016',
#  'art',
#  ...]

# %% [markdown]
# #### Testes Unitários

# %%
test_file = open(dodfs_n_files[1], "r")
test_txt = test_file.read()
print(dodfs_n_files[1])
simbolos = execute_regex(simbolo_rule, test_txt)
print(len(simbolos))
simbolos
# Out:
# ./data/dodfs_txt_barra_n/2019/07_Julho/DODF 135 19-07-2019 INTEGRA.txt
# 98
# ['DFA - 1 5 ',
#  'DFA-14',
#  'DFA-15',
#  'DFA-14',
#  'DFA-14',
#  'D FA -\n14',
#  'DFG-14',
#  'CNE-07',
#  'DFG-14',
#  'CNE-06',
#  'CNE-06',
#  'CNE-07',
#  'DFG-\n14',
#  'DFA-14',
#  'DFA-14',
#  'CNE-07',
#  'CNE-05',
#  'CNE-05',
#  'DFA-14',
#  'DFA-\n14',
#  'DFG-14',
#  'DFG-\n14',
#  'CNE-02',
#  'DFA-12',
#  'DFA-12',
#  'DFA-12',
#  'DFA-12',
#  'DFA-14',
#  'DFA-14',
#  'DFA-12',
#  'D FA-12',
#  'DFA-12',
#  'DFA-12',
#  'DFA-14',
#  'DFA-14',
#  'D FA - 1 7 ',
#  'DFA-17',
#  'DFA-17',
#  'DFA-17',
#  'DFA-13',
#  'DFA-13',
#  'DFA-13',
#  'DFG-07',
#  'DFG-07',
#  'DFG-07',
#  'DFG-07',
#  'DFG-05',
#  'DFG-11',
#  'DFG-11',
#  'DFG-07',
#  'DFG-07',
#  'DFG-07',
#  'DFG-07',
#  'DFG-07',
#  'DFG-07',
#  'DFG-11',
#  'DFG-11',
#  'DFG-11',
#  'DFG-11',
#  'DFG-11',
#  'DFG-11',
#  'DFA-14',
#  'DFA-14',
#  'DFA-12',
#  'DFG-14',
#  'DFA-\n10',
#  'DFA-10',
#  'DFA-10',
#  'DFA-10',
#  'DFG-14',
#  'DFG-14',
#  'DFA-14',
#  'DFA-10',
#  'DFA-14',
#  'DFA-10',
#  'DFG-14',
#  'FGE-03',
#  'FGE-03',
#  'FGE-05',
#  'FGE-05',
#  'FGE-03',
#  'FGE-03',
#  'FGE-03',
#  'FGE-03',
#  'FGE-05',
#  'FGE-05',
#  'FGE-03',
#  'CNE-02',
#  'CNE-04',
#  'DFG-14',
#  'CNE-07',
#  'DFG-13',
#  'DFA-05',
#  'DFA-05',
#  'DFG-13',
#  'DFG-13',
#  'DFG-\n13',
#  'DFG-13']
