# %%
import re
import pandas as pd
from os import listdir
from os.path import isfile, join

# %%
def print_dataframe(df):
    style_df = (df.style.set_properties(**{'text-align': 'left'})
                                        .set_table_styles([ dict(selector='th',
                                                                 props=[('text-align','left')])])
                   )
    return style_df

def get_txts(path):
    years = [join(path, x) for x in listdir(path) if not isfile(join(path, x))]
    txts = []
    for year in years:
        months = [join(year, x) for x in listdir(year) if not isfile(join(year, x))]
        for month in months:
            txts += [join(month, x) for x in listdir(month) if isfile(join(month, x))]
    return txts

# %%
dodfs_space_dir = "./dodfs_txt_espaco"
dodfs_space_files = get_txts(dodfs_space_dir)

dodfs_n_dir = "./dodfs_txt_barra_n"
dodfs_n_files = get_txts(dodfs_n_dir)

output = "./results"

# %%
class Regex:
    
    def __init__(self, text):
        self._text = text
        self._raw_acts = {}
        self._acts = []
        self._columns = []
        self.data_frame = pd.DataFrame()
    
    def find_all(self, rule, flag=0):
        return re.findall(rule, self._text, flags=flag)
    
    def find_in_act(self, rule, act):
        match = re.search(rule, act) 
        if match:
            return match.groups()
        return "nan"
    
    def _build_dataframe(self):
        if len(self._acts) > 0:
            df = pd.DataFrame(self._acts, columns=self._columns)
            #df.columns = self._columns
            return df
        return pd.DataFrame()

# %% [markdown]
# # Exoneração

# %%
# Classe Nomeação para cargos comissionados
class Exoneracao(Regex):
    
    def __init__(self,text):
        super().__init__(text)
        self._columns = ['nome','matricula','simbolo','cargo_comissao','lotacao','orgao','vigencia','pedido',
                         'cargo_efetivo','siape','motivo']
        self.rules = {
            "nome": r"([A-ZÀ-Ž\s]+[A-ZÀ-Ž])",
            "matricula": r"matr[í|i]cula\s?n?o?\s([\s\S]*?)[,|\s]",
            "simbolo": r"[S|s][í|i]mbolo\s?n?o?\s([\s\S]*?)[,|\s]",
            "cargo_comissao": "",
            "lotacao": "",
            "orgao": "",
            "vigencia": "",
            "pedido": r"(a pedido)",
            "cargo_efetivo": "",
            "siape": r"[S|s][I|i][A|a][P|p][E|e]\s[N|n]*[o|O]*\s?([\s\S]*?)[,| | .]",
            "motivo": ""
        }
        self._raw_acts = self._extract_instances()
        self._acts = self._acts_props()
        self.data_frame = self._build_dataframe()
        
        
    
    def _act_props(self, act_raw):
        act = {}
        for key in self.rules:
            try:
                act[key], = self.find_in_act(self.rules[key], act_raw)
            except:
                act[key] = "nan"
        return act
    
    def _acts_props(self):
        acts = []
        for raw in self._raw_acts:
            act = self._act_props(raw)
            acts.append(act)
        return acts        
        
    def _extract_instances(self):
        start = r"(EXONERAR)"
        body = r"([\s\S]*?)"
        end = "\."
        rule = start + body + end
        found = self.find_all(rule)
        results = []
        for instance in found:
            start, body = instance
            results.append(body)
            
        return results

# %%
res_dfs = []
l_ret = []
for txt in dodfs_n_files:
    txt_str = open(txt, "r").read()
    ret = Exoneracao(txt_str)
    l_ret.append(ret)
    if not ret.data_frame.empty:
        res_dfs.append(ret.data_frame)

rets_final = pd.concat([pd.DataFrame(df) for df in res_dfs],
                        ignore_index=True)
#print_dataframe(rets_final)

# %%
l_ret[13]._raw_acts[10]
# Out:
# ' EDIRANI SANTOS ARAUJO do Cargo em Comissao, Simbolo DFA-10, de Assessor\nTecnico, da Agencia de Atendimento ao Trabalhador do Guara, da Diretoria de Acoes para o Trabalhador,\nda Coordenacao de Acoes para o Trabalhador e o Empregador, da Subsecretaria de Atendimento ao\nTrabalhador e Empregador, da Secretaria Adjunta do Trabalho, da Secretaria de Estado de Trabalho do\nDistrito Federal'

# %%
l_ret[0]._acts[13]
# Out:
# {'nome': ' ALVARO GOMES DA SILVA JUNIOR',
#  'matricula': 'nan',
#  'simbolo': 'CNE-',
#  'cargo_comissao': 'nan',
#  'lotacao': 'nan',
#  'orgao': 'nan',
#  'vigencia': 'nan',
#  'pedido': 'a pedido',
#  'cargo_efetivo': 'nan',
#  'siape': 'nan',
#  'motivo': 'nan'}

# %%
def _build_dataframe(_acts, _columns):
    if len(_acts) > 0:
        df = pd.DataFrame(_acts)
        df.columns = _columns
        return df
    return pd.DataFrame()
_build_dataframe(ret._acts, ret._columns)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
rets_final
# Out:
#                                             nome  matricula simbolo  \
# 0                     MATHEUS DE ARAUJO SIQUEIRA        nan  DFG-14
# 1                 MARCIO HUMBERTO DA SILVA ROCHA        nan  DFA-10
# 2                       ADAILTON LINO DOS SANTOS        nan  DFG-14
# 3                            BRUNA ESTRELA NUNES        nan  DFG-14
# 4               IVANUZA ARAUJO FERREIRA DE SOUZA        nan  DFG-14
# 5                          RODRIGO NUNES SANTANA        nan  DFG-14
# 6                   KATIA REGINA DA SILVA CABRAL        nan  DFA-10
# 7               PEDRO HENRIQUE MONTEIRO DE JESUS        nan  DFA-10
# 8                      ROBSON ELIAS SOUSA FERRAZ        nan  DFA-08
# 9                          GLAUCILENE ROSA SASSI        nan  DFG-14
# 10                  HENRIQUE DE OLIVEIRA BOITEUX        nan  DFA-12
# 11                  DANIEL TELES PALMEIRA BORGES        nan     nan
# 12                   CLAUDIA RIBEIRO DE CARVALHO        nan     nan
# 13                  ALVARO GOMES DA SILVA JUNIOR        nan    CNE-
# 14                              LUIZ KAZUO HATAE        nan  CNE-07
# 15                      FRANCISCO DE ASSIS PIRES        nan  DFG-14
# 16                      EVELYNE NUNES DOS SANTOS        nan     nan
# 17                   ENRIQUE JOSE MATUTE CAROZZI         no     nan
# 18            ARIANE\nROBERTA DE SOUZA GUIMARAES         no     nan
# 19                                    ADRIANA\nD        nan     nan
# 20                                     ADRIANA D        nan     nan
# 21                       HARRISON K R AW C Z Y K        nan     nan
# 22                             \nKELLY BIZINOTTO        nan     nan
# 23                    KELLY JORDANY LEONES LOPES        nan     nan
# 24                         ALUISIO DIAS FERREIRA  0172573-4  DFG-11
# 25        MAYARA DE SOUZA CORREIA PAIXAO BATISTA  1671265-X  DFG-07
# 26                          FABIANO DUARTE DUTRA        nan     nan
# 27       CINTIA SIQUEIRA SOUSA PELEGRINI BARRETO        nan     nan
# 28                 RUBER PAULO DE OLIVIERA GOMES        nan     nan
# 29                       CALIL SALOMAO ABUD NETO   0198861-  DFG-11
# ...                                          ...        ...     ...
# 13171        LUCIANA STEFANE DE ALMEIDA DIONISIO        nan     nan
# 13172      \nLUCIANA STEFANE DE ALMEIDA DIONISIO        nan     nan
# 13173                     BRUNO RAFAEL DE AGUIAR        nan     nan
# 13174                        CELI MARIA DA SILVA  1696933-2  CNE-07
# 13175                                          I        nan     nan
# 13176        RONALDO APARECIDO DE OLIVEIRA KLEIN        nan     nan
# 13177        RONALDO APARECIDO DE OLIVEIRA KLEIN        nan     nan
# 13178                      SABRINA LEITE PESSOTI         no     nan
# 13179                     CLEYTON TEIXEIRA GOMES                nan
# 13180              LEONARDO ERIC FERREIRA GANDRA         no     nan
# 13181             KARINE LOPES RIBEIRO GONCALVES         no     nan
# 13182               RODOLFO ALVES PAULO DE SOUZA        nan     nan
# 13183                MARINA DA SILVEIRA \nARAUJO        nan     nan
# 13184           ANA LUCIADO \nNASCIMENTO MOREIRA        nan     nan
# 13185                   ALESSANDRO JOSE DA SILVA   16971450  CNE-03
# 13186   URSULA REGINA LEITE DA \nSILVA VERISSIMO        nan  CNE-07
# 13187                 ANA MARIA ALVES \nSHIBATTA        nan   CC-08
# 13188                    POLYANNA RAMOS DE SOUZA        nan   CC-08
# 13189                SIMONE DA CONCEICAO \nALVES        nan   CC-05
# 13190       CAP QOPM FLAVIO SILVESTRE DE ALENCAR        nan     nan
# 13191           SGT QPPMC GILMAR GOMES DE FARIAS        nan     nan
# 13192                    MURILO CESARIO DE SOUZA        nan     nan
# 13193          BIANCA BORGES BUENO DE FIGUEIREDO                nan
# 13194          LUIZ GUILHERME MOREIRA CAVALCANTI        nan   CC-04
# 13195                       VERA ALVES LAMOUNIER        nan    CNE-
# 13196                     ROMERO COELHO DA ROCHA        nan   CC-08
# 13197        PEDRO HENRIQUE BARROS \nVASCONCELOS        nan   CC-06
# 13198              PEDRO BATISTA DA SILVA JUNIOR        nan   CC-06
# 13199              HILDA PEREIRA MADEIRA \nMOITA        nan  CNE-02
# 13200            YARA FERNANDA OLIMPIO \nBRANDAO        nan  CNE-02
#
#       cargo_comissao lotacao orgao vigencia    pedido cargo_efetivo siape  \
# 0                nan     nan   nan      nan       nan           nan   nan
# 1                nan     nan   nan      nan       nan           nan   nan
# 2                nan     nan   nan      nan       nan           nan   nan
# 3                nan     nan   nan      nan       nan           nan   nan
# 4                nan     nan   nan      nan       nan           nan   nan
# 5                nan     nan   nan      nan       nan           nan   nan
# 6                nan     nan   nan      nan       nan           nan   nan
# 7                nan     nan   nan      nan       nan           nan   nan
# 8                nan     nan   nan      nan       nan           nan   nan
# 9                nan     nan   nan      nan  a pedido           nan   nan
# 10               nan     nan   nan      nan       nan           nan   nan
# 11               nan     nan   nan      nan       nan           nan   nan
# 12               nan     nan   nan      nan       nan           nan   nan
# 13               nan     nan   nan      nan  a pedido           nan   nan
# 14               nan     nan   nan      nan       nan           nan   nan
# 15               nan     nan   nan      nan       nan           nan   nan
# 16               nan     nan   nan      nan       nan           nan   nan
# 17               nan     nan   nan      nan       nan           nan   nan
# 18               nan     nan   nan      nan       nan           nan   nan
# 19               nan     nan   nan      nan       nan           nan   nan
# 20               nan     nan   nan      nan  a pedido           nan   nan
# 21               nan     nan   nan      nan  a pedido           nan   nan
# 22               nan     nan   nan      nan  a pedido           nan   nan
# 23               nan     nan   nan      nan       nan           nan   nan
# 24               nan     nan   nan      nan       nan           nan   nan
# 25               nan     nan   nan      nan       nan           nan   nan
# 26               nan     nan   nan      nan       nan           nan   nan
# 27               nan     nan   nan      nan       nan           nan   nan
# 28               nan     nan   nan      nan       nan           nan   nan
# 29               nan     nan   nan      nan       nan           nan   nan
# ...              ...     ...   ...      ...       ...           ...   ...
# 13171            nan     nan   nan      nan       nan           nan   nan
# 13172            nan     nan   nan      nan  a pedido           nan   nan
# 13173            nan     nan   nan      nan  a pedido           nan   nan
# 13174            nan     nan   nan      nan       nan           nan   nan
# 13175            nan     nan   nan      nan       nan           nan   nan
# 13176            nan     nan   nan      nan       nan           nan   nan
# 13177            nan     nan   nan      nan  a pedido           nan   nan
# 13178            nan     nan   nan      nan  a pedido           nan   nan
# 13179            nan     nan   nan      nan  a pedido           nan   nan
# 13180            nan     nan   nan      nan  a pedido           nan   nan
# 13181            nan     nan   nan      nan  a pedido           nan   nan
# 13182            nan     nan   nan      nan       nan           nan   nan
# 13183            nan     nan   nan      nan       nan           nan   nan
# 13184            nan     nan   nan      nan       nan           nan   nan
# 13185            nan     nan   nan      nan       nan           nan   nan
# 13186            nan     nan   nan      nan       nan           nan   nan
# 13187            nan     nan   nan      nan       nan           nan   nan
# 13188            nan     nan   nan      nan  a pedido           nan   nan
# 13189            nan     nan   nan      nan       nan           nan   nan
# 13190            nan     nan   nan      nan       nan           nan   nan
# 13191            nan     nan   nan      nan       nan           nan   nan
# 13192            nan     nan   nan      nan       nan           nan   nan
# 13193            nan     nan   nan      nan  a pedido           nan   nan
# 13194            nan     nan   nan      nan       nan           nan   nan
# 13195            nan     nan   nan      nan       nan           nan   nan
# 13196            nan     nan   nan      nan       nan           nan   nan
# 13197            nan     nan   nan      nan       nan           nan   nan
# 13198            nan     nan   nan      nan  a pedido           nan   nan
# 13199            nan     nan   nan      nan       nan           nan   nan
# 13200            nan     nan   nan      nan       nan           nan   nan
#
#       motivo
# 0        nan
# 1        nan
# 2        nan
# 3        nan
# 4        nan
# 5        nan
# 6        nan
# 7        nan
# 8        nan
# 9        nan
# 10       nan
# 11       nan
# 12       nan
# 13       nan
# 14       nan
# 15       nan
# 16       nan
# 17       nan
# 18       nan
# 19       nan
# 20       nan
# 21       nan
# 22       nan
# 23       nan
# 24       nan
# 25       nan
# 26       nan
# 27       nan
# 28       nan
# 29       nan
# ...      ...
# 13171    nan
# 13172    nan
# 13173    nan
# 13174    nan
# 13175    nan
# 13176    nan
# 13177    nan
# 13178    nan
# 13179    nan
# 13180    nan
# 13181    nan
# 13182    nan
# 13183    nan
# 13184    nan
# 13185    nan
# 13186    nan
# 13187    nan
# 13188    nan
# 13189    nan
# 13190    nan
# 13191    nan
# 13192    nan
# 13193    nan
# 13194    nan
# 13195    nan
# 13196    nan
# 13197    nan
# 13198    nan
# 13199    nan
# 13200    nan
#
# [13201 rows x 11 columns]
